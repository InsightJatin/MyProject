# %% [markdown]
# # US State-wise Customer & Product Demand Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("SampleSuperstore.csv")

# %%
df.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: count, Length: 531, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.duplicated().sum()
# Out:
# np.int64(17)

# %%
duplicates = df[df.duplicated(keep=False)]
duplicates
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 568   Standard Class    Corporate  United States        Seattle    Washington
# 591   Standard Class     Consumer  United States          Salem        Oregon
# 935   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 950   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 1186  Standard Class    Corporate  United States        Seattle    Washington
# 1479  Standard Class     Consumer  United States  San Francisco    California
# 2803  Standard Class     Consumer  United States  San Francisco    California
# 2807    Second Class     Consumer  United States        Seattle    Washington
# 2836  Standard Class     Consumer  United States    Los Angeles    California
# 3127  Standard Class     Consumer  United States  New York City      New York
# 3405  Standard Class  Home Office  United States       Columbus          Ohio
# ...

# %%
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data = df.groupby('State')['Sales'].sum()
top20 = data.sort_values(ascending=False).head(20)
top20.plot(kind='bar')
plt.title("Top 20 States")
plt.show()

# %%
grp = df.groupby('State')['Sales'].sum().nlargest(20).index
top_data = df[df['State'].isin(grp)]
final_data = top_data.groupby(['State','Category'])['Sales'].sum().unstack()
final_data.plot(kind='bar',stacked=True)
plt.title("Sales by category (Top 20)")
# Out:
# Text(0.5, 1.0, 'Sales by category (Top 20)')

# %%
region_profit = df.groupby('Region')['Profit'].sum()
region_profit.plot(kind='bar',color='magenta')
plt.title("Profit by region")
plt.show()

# %%
region_profit = df.groupby('Region')['Sales'].sum()
region_profit.plot(kind='bar',color='g')
plt.title("profit by region")
plt.show()

# %%
state_discount = df.groupby('State')['Discount'].mean()
state_discount.plot(kind='bar',color='pink')
plt.title("avg discount by ")
plt.show()

# %%
region_profit = df.groupby('State')['Sales'].sum()
region_profit.plot(kind='bar',color='b')
plt.title("sals by state")
plt.show()

# %%
plt.figure(figsize=(10,6))
region_profit = df.groupby('Sales')['Profit'].sum()
region_profit.plot(kind='bar',color='magenta')
plt.title("profit by state")
plt.show()

# %%
sns.histplot(df['Profit'],bins=30)
plt.title("Dstribution of Profit")
plt.show()

# %%
sns.boxplot(x='Category',y='Sales',data=df)
plt.title("Sales Distribution By Caregory")
plt.show()

# %%
sns.boxplot(x='Category',y='Profit',data=df)
plt.title("Profit Dstributon By Category")
plt.show()

# %%
sns.scatterplot(x='Discount',y='Profit',data=df)
plt.title("Discount vs Profit")
plt.show()

# %%
sns.boxplot(x='Region',y='Profit',data=df)
plt.title("profit distribution by region")
plt.show()

# %%
sns.boxplot(x='Segment',y='Sales',data=df)
plt.title("slaes dstribution by segment")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Sub-Category',y='Profit',data=df)
plt.xticks(rotation=90)
plt.title("profit distribution by sub-category")
plt.show()

# %%
region_profit = df.groupby('Sales')['Profit'].sum()
top25 = region_profit.sort_values(ascending=False).head(25)
top25.plot(kind='bar',color='magenta',figsize=(12,6))
plt.title("profit by top 25 state")
plt.ylabel("profit")
plt.show()
