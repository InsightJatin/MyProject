# %%
import pandas as pd

# %%
p = pd.read_csv('Car.csv')

# %%
p
# Out:
#       Unnamed: 0                          name  year  selling_price  \
# 0              0        Maruti Swift Dzire VDI  2014         450000
# 1              1  Skoda Rapid 1.5 TDI Ambition  2014         370000
# 2              2      Honda City 2017-2020 EXi  2006         158000
# 3              3     Hyundai i20 Sportz Diesel  2010         225000
# 4              4        Maruti Swift VXI BSIII  2007         130000
# ...          ...                           ...   ...            ...
# 8122        8122             Hyundai i20 Magna  2013         320000
# 8123        8123         Hyundai Verna CRDi SX  2007         135000
# 8124        8124        Maruti Swift Dzire ZDi  2009         382000
# 8125        8125               Tata Indigo CR4  2013         290000
# 8126        8126               Tata Indigo CR4  2013         290000
#
#       km_driven    fuel seller_type transmission                 owner  \
# 0        145500  Diesel  Individual       Manual           First Owner
# ...

# %%
p = p.iloc[0:,1:]

# %%
p.head(10)
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# 5         Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6          Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                    Maruti 800 DX BSII  2001          45000       5000
# 8                      Toyota Etios VXD  2011         350000      90000
# 9  Ford Figo Diesel Celebration Edition  2013         200000     169000
#
#      fuel seller_type transmission         owner     mileage   engine  \
# 0  Diesel  Individual       Manual   First Owner   23.4 kmpl  1248 CC
# ...

# %%
p.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           221
# seats            221
# dtype: int64

# %%
p = p.drop(8126)

# %%
p.duplicated().any()
# Out:
# np.True_

# %%
p.duplicated().sum()
# Out:
# np.int64(1201)

# %%
p.drop_duplicates(inplace=True)

# %%
p.shape
# Out:
# (6925, 13)

# %%
p["seats"].value_counts()
# Out:
# seats
# 5.00     5254
# 7.00      966
# 8.00      221
# 4.00      124
# 9.00       74
# 6.00       57
# 10.00      18
# 2.00        2
# 14.00       1
# Name: count, dtype: int64

# %%
p["seats"] = p["seats"].fillna(5)

# %%
p["fuel"].value_counts()
# Out:
# fuel
# Diesel    3755
# Petrol    3077
# CNG         55
# LPG         38
# Name: count, dtype: int64

# %%
p = p.dropna()

# %%
p = p.drop(columns="torque")

# %%
def abc(x):
    return x.split()[0]

p["max_power"] = p["max_power"].apply(abc)

# %%
p["max_power"].dtype
# Out:
# dtype('O')

# %%
p = p.reset_index(drop=True)

# %%
p.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage           object
# engine            object
# max_power         object
# seats            float64
# dtype: object

# %%
p["max_power"] = p["max_power"].astype("float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[169], line 1
# ----> 1 p["max_power"] = p["max_power"].astype("float")
#
# File D:\New folder\Anaconda\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File D:\New folder\Anaconda\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# ...

# %%
l = []
for i in range(len(p)):
    try:
        float(p.iloc[i,-2])
    except:
        l.append(i)
print(l)
# Out:
# [789]

# %%
p.iloc[789]
# Out:
# name             Hyundai EON Era
# year                        2011
# selling_price             160000
# km_driven                  57000
# fuel                      Petrol
# seller_type           Individual
# transmission              Manual
# owner                First Owner
# mileage                21.1 kmpl
# engine                    814 CC
# max_power                   .bhp
# seats                       5.00
# Name: 789, dtype: object

# %%
p.loc[789,'max_power'] = None

# %%
p = p.drop(index=l)
p = p.reset_index(drop=True)

# %%
p['max_power'] = p['max_power'].astype("float")

# %%
p.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage           object
# engine            object
# max_power        float64
# seats            float64
# dtype: object

# %%
def qwe(y):
    return y.split()[0]

p["engine"] = p["engine"].apply(qwe)

# %%
p["engine"] = p["engine"].astype("float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 p["engine"] = p["engine"].astype("float")
#
# File D:\New folder\Anaconda\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File D:\New folder\Anaconda\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# ...

# %%
f = [] 
for i in range(len(p)):
    try:
        float(p.iloc[i,-3])
    except:
        f.append(i)
print(f)
# Out:
# [915]

# %%
p.iloc[915]
# Out:
# name             Maruti Wagon R LXI BS IV
# year                                 2012
# selling_price                      220000
# km_driven                          360003
# fuel                               Petrol
# seller_type                    Individual
# transmission                       Manual
# owner                        Second Owner
# mileage                         18.9 kmpl
# engine                                 CC
# max_power                           67.10
# seats                                5.00
# Name: 915, dtype: object

# %%
p = p.drop(index=f)
p = p.reset_index(drop=True)

# %%
p["engine"] = p["engine"].astype("float")

# %%
def asd(z):
    return z.split()[0]

p["mileage"] = p["mileage"].apply(asd)

# %%
p["mileage"] = p["mileage"].astype("float")

# %%
p.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage  engine  max_power  seats
# 0  Individual       Manual   First Owner    23.40 1248.00      74.00   5.00
# 1  Individual       Manual  Second Owner    21.14 1498.00     103.52   5.00
# 2  Individual       Manual   Third Owner    17.70 1497.00      78.00   5.00
# 3  Individual       Manual   First Owner    23.00 1396.00      90.00   5.00
# 4  Individual       Manual   First Owner    16.10 1298.00      88.20   5.00

# %%
p.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage          float64
# engine           float64
# max_power        float64
# seats            float64
# dtype: object

# %%
p["owner"].value_counts()
# Out:
# owner
# First Owner             4175
# Second Owner            1887
# Third Owner              493
# Fifth                     82
# Fourth & Above Owner      73
# Test Drive Car             5
# Name: count, dtype: int64

# %%
p["owner"] = p["owner"].replace({"Fifth":"Fourth & Above Owner","Test Drive Car":"Fourth & Above Owner"})

# %%
p["owner"].value_counts()
# Out:
# owner
# First Owner             4175
# Second Owner            1887
# Third Owner              493
# Fourth & Above Owner     160
# Name: count, dtype: int64

# %%
p.groupby("owner")["selling_price"].mean()
# Out:
# owner
# First Owner            620621.67
# Fourth & Above Owner   362340.58
# Second Owner           393978.42
# Third Owner            289751.55
# Name: selling_price, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.violinplot(x="owner",y = "selling_price",data=p)
plt.title("s.p. -> ownervise")
plt.show()

# %%
p["transmission"].value_counts()
# Out:
# transmission
# Manual       6140
# Automatic     575
# Name: count, dtype: int64

# %%
p.groupby("transmission")["selling_price"].mean()
# Out:
# transmission
# Automatic   1322916.50
# Manual       451901.91
# Name: selling_price, dtype: float64

# %%
sns.violinplot(x="transmission",y="selling_price",data=p)
plt.title("s.p. -> transmission")
plt.show()

# %%
p.groupby("seller_type")["selling_price"].describe()
# Out:
#                    count      mean        std       min       25%       50%  \
# seller_type
# Dealer            666.00 936708.66 1000188.69  60000.00 430499.75 625000.00
# Individual       6022.00 480258.68  416902.67  29999.00 244250.00 400000.00
# Trustmark Dealer   27.00 718111.11  338380.46 225000.00 550000.00 650000.00
#
#                        75%         max
# seller_type
# Dealer           947500.00  6523000.00
# Individual       608750.00 10000000.00
# Trustmark Dealer 850000.00  2000000.00

# %%
sns.violinplot(x="seller_type",y="selling_price",data=p)
plt.title("s.p. -> seller_type")
plt.show()

# %%
p["fuel"].value_counts()
# Out:
# fuel
# Diesel    3658
# Petrol    2971
# CNG         51
# LPG         35
# Name: count, dtype: int64

# %%
p.groupby("fuel")["selling_price"].describe()
# Out:
#          count      mean       std       min       25%       50%       75%  \
# fuel
# CNG      51.00 317666.61 102366.65 120000.00 227500.00 330000.00 394500.00
# Diesel 3658.00 647996.11 589142.67  45000.00 325000.00 525000.00 750000.00
# LPG      35.00 210885.71  79828.04  54000.00 150000.00 200000.00 275000.00
# Petrol 2971.00 384181.41 389566.05  29999.00 196000.00 320000.00 500000.00
#
#                max
# fuel
# CNG      545000.00
# Diesel  7200000.00
# LPG      375000.00
# Petrol 10000000.00

# %%
p["fuel"] = p["fuel"].replace({"CNG":"Eco","LPG":"Eco"})

# %%
p["fuel"].value_counts()
# Out:
# fuel
# Diesel    3658
# Petrol    2971
# Eco         86
# Name: count, dtype: int64

# %%
sns.violinplot(x="fuel",y="selling_price",data=p)
plt.title("s.p. -> fuel")
plt.show()

# %%
plt.scatter(p["km_driven"],p["selling_price"])
plt.xlabel("kilometers driven")
plt.ylabel("price")
plt.show()

# %%
p["name"]
# Out:
# 0                  Maruti Swift Dzire VDI
# 1            Skoda Rapid 1.5 TDI Ambition
# 2                Honda City 2017-2020 EXi
# 3               Hyundai i20 Sportz Diesel
# 4                  Maruti Swift VXI BSIII
#                       ...
# 6710    Maruti Wagon R VXI BS IV with ABS
# 6711           Hyundai i20 Magna 1.4 CRDi
# 6712                    Hyundai i20 Magna
# 6713                Hyundai Verna CRDi SX
# 6714               Maruti Swift Dzire ZDi
# Name: name, Length: 6715, dtype: object

# %%
def zxc(a):
    brand = a.split()[0]
    model = a.split()[1]
    return brand
p["name"] = p["name"].apply(zxc)

# %%
p["name"].value_counts()
# Out:
# name
# Maruti           2088
# Hyundai          1213
# Mahindra          709
# Tata              633
# Honda             361
# Ford              353
# Toyota            324
# Chevrolet         216
# Renault           206
# Volkswagen        173
# Nissan             73
# Skoda              69
# Datsun             57
# Mercedes-Benz      46
# BMW                45
# Fiat               39
# Audi               33
# Jeep               22
# Mitsubishi         11
# Volvo               9
# Jaguar              8
# Isuzu               4
# Ambassador          4
# Force               4
# Land                3
# Kia                 3
# Daewoo              3
# MG                  3
# Ashok               1
# Lexus               1
# Opel                1
# Name: count, dtype: int64

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
q = p.groupby("name")
m = q["selling_price"].mean()

# %%
m
# Out:
# name
# Ambassador       124000.00
# Ashok            300000.00
# Audi            2422363.55
# BMW             2826222.22
# Chevrolet        268349.63
# Daewoo            77000.00
# Datsun           316017.49
# Fiat             311666.62
# Force            841250.00
# Ford             508161.43
# Honda            574460.21
# Hyundai          466854.45
# Isuzu           1752500.00
# Jaguar          2748250.00
# Jeep            1789227.23
# Kia             1372666.67
# Land            2716666.67
# Lexus           5150000.00
# MG              1783333.33
# Mahindra         623684.02
# Maruti           394057.86
# Mercedes-Benz   2253347.83
# Mitsubishi       758636.36
# Nissan           456616.38
# Opel              68000.00
# Renault          449694.14
# Skoda            594217.35
# Tata             348941.40
# Toyota           948354.87
# Volkswagen       479976.86
# Volvo           4036111.11
# Name: selling_price, dtype: float64

# %%
len(m)
# Out:
# 31

# %%
def bnm(q):
    mean=m[q]
    if mean>2000000:
        return 2
    elif mean>500000 and mean<=2000000:
        return 1
    else:
        return 0

p["name"] = p["name"].apply(bnm)
p["name"].value_counts()
# Out:
# name
# 0    4707
# 1    1863
# 2     145
# Name: count, dtype: int64

# %%
p.dtypes
# Out:
# name               int64
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage          float64
# engine           float64
# max_power        float64
# seats            float64
# dtype: object

# %%
numeric = p[["selling_price","km_driven","mileage","max_power","engine"]]

# %%
x = numeric.corr()

# %%
x
# Out:
#                selling_price  km_driven  mileage  max_power  engine
# selling_price           1.00      -0.16    -0.11       0.69    0.44
# km_driven              -0.16       1.00    -0.20       0.04    0.25
# mileage                -0.11      -0.20     1.00      -0.38   -0.58
# max_power               0.69       0.04    -0.38       1.00    0.68
# engine                  0.44       0.25    -0.58       0.68    1.00

# %%
sns.heatmap(x)
# Out:
# <Axes: >

# %%
p.dtypes
# Out:
# name               int64
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage          float64
# engine           float64
# max_power        float64
# seats            float64
# dtype: object

# %%
p
# Out:
#       name  year  selling_price  km_driven    fuel seller_type transmission  \
# 0        0  2014         450000     145500  Diesel  Individual       Manual
# 1        1  2014         370000     120000  Diesel  Individual       Manual
# 2        1  2006         158000     140000  Petrol  Individual       Manual
# 3        0  2010         225000     127000  Diesel  Individual       Manual
# 4        0  2007         130000     120000  Petrol  Individual       Manual
# ...    ...   ...            ...        ...     ...         ...          ...
# 6710     0  2013         260000      50000  Petrol  Individual       Manual
# 6711     0  2014         475000      80000  Diesel  Individual       Manual
# 6712     0  2013         320000     110000  Petrol  Individual       Manual
# 6713     0  2007         135000     119000  Diesel  Individual       Manual
# 6714     0  2009         382000     120000  Diesel  Individual       Manual
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
on = OneHotEncoder()

# %%
a = on.fit_transform(p[["owner"]]).toarray()

# %%
enco = pd.DataFrame(a,columns=on.get_feature_names_out())

# %%
pr =pd.concat([enco,p],axis=1)

# %%
pr
# Out:
#       owner_First Owner  owner_Fourth & Above Owner  owner_Second Owner  \
# 0                  1.00                        0.00                0.00
# 1                  0.00                        0.00                1.00
# 2                  0.00                        0.00                0.00
# 3                  1.00                        0.00                0.00
# 4                  1.00                        0.00                0.00
# ...                 ...                         ...                 ...
# 6710               0.00                        0.00                1.00
# 6711               0.00                        0.00                1.00
# 6712               1.00                        0.00                0.00
# 6713               0.00                        1.00                0.00
# 6714               1.00                        0.00                0.00
#
#       owner_Third Owner  name  year  selling_price  km_driven    fuel  \
# ...

# %%
pr = pr.drop(["owner"],axis=1)

# %%
b = on.fit_transform(pr[["transmission"]]).toarray()

# %%
en = pd.DataFrame(b,columns=on.get_feature_names_out())

# %%
pro = pd.concat([en,pr],axis=1)

# %%
pro
# Out:
#       transmission_Automatic  transmission_Manual  owner_First Owner  \
# 0                       0.00                 1.00               1.00
# 1                       0.00                 1.00               0.00
# 2                       0.00                 1.00               0.00
# 3                       0.00                 1.00               1.00
# 4                       0.00                 1.00               1.00
# ...                      ...                  ...                ...
# 6710                    0.00                 1.00               0.00
# 6711                    0.00                 1.00               0.00
# 6712                    0.00                 1.00               1.00
# 6713                    0.00                 1.00               0.00
# 6714                    0.00                 1.00               1.00
#
#       owner_Fourth & Above Owner  owner_Second Owner  owner_Third Owner  name  \
# ...

# %%
pro = pro.drop(["transmission"],axis=1)

# %%
c = on.fit_transform(pro[["seller_type"]]).toarray()

# %%
e = pd.DataFrame(c,columns=on.get_feature_names_out())

# %%
proj = pd.concat([e,pro],axis=1)

# %%
proj
# Out:
#       seller_type_Dealer  seller_type_Individual  \
# 0                   0.00                    1.00
# 1                   0.00                    1.00
# 2                   0.00                    1.00
# 3                   0.00                    1.00
# 4                   0.00                    1.00
# ...                  ...                     ...
# 6710                0.00                    1.00
# 6711                0.00                    1.00
# 6712                0.00                    1.00
# 6713                0.00                    1.00
# 6714                0.00                    1.00
#
#       seller_type_Trustmark Dealer  transmission_Automatic  \
# 0                             0.00                    0.00
# 1                             0.00                    0.00
# 2                             0.00                    0.00
# 3                             0.00                    0.00
# 4                             0.00                    0.00
# ...

# %%
proj =proj.drop(["seller_type"],axis=1)

# %%
proj = proj.rename(columns={'seller_type_Trustmark Dealer':'seller_type_Trustmark_Dealer'})

# %%
proj
# Out:
#       seller_type_Dealer  seller_type_Individual  \
# 0                   0.00                    1.00
# 1                   0.00                    1.00
# 2                   0.00                    1.00
# 3                   0.00                    1.00
# 4                   0.00                    1.00
# ...                  ...                     ...
# 6710                0.00                    1.00
# 6711                0.00                    1.00
# 6712                0.00                    1.00
# 6713                0.00                    1.00
# 6714                0.00                    1.00
#
#       seller_type_Trustmark_Dealer  transmission_Automatic  \
# 0                             0.00                    0.00
# 1                             0.00                    0.00
# 2                             0.00                    0.00
# 3                             0.00                    0.00
# 4                             0.00                    0.00
# ...

# %%
d = on.fit_transform(proj[["fuel"]]).toarray()

# %%
e = pd.DataFrame(d,columns=on.get_feature_names_out())

# %%
project = pd.concat([e,proj],axis=1)

# %%
project
# Out:
#       fuel_Diesel  fuel_Eco  fuel_Petrol  seller_type_Dealer  \
# 0            1.00      0.00         0.00                0.00
# 1            1.00      0.00         0.00                0.00
# 2            0.00      0.00         1.00                0.00
# 3            1.00      0.00         0.00                0.00
# 4            0.00      0.00         1.00                0.00
# ...           ...       ...          ...                 ...
# 6710         0.00      0.00         1.00                0.00
# 6711         1.00      0.00         0.00                0.00
# 6712         0.00      0.00         1.00                0.00
# 6713         1.00      0.00         0.00                0.00
# 6714         1.00      0.00         0.00                0.00
#
#       seller_type_Individual  seller_type_Trustmark_Dealer  \
# 0                       1.00                          0.00
# 1                       1.00                          0.00
# ...

# %%
project =project.drop(["fuel"],axis=1)

# %%
project.dtypes
# Out:
# fuel_Diesel                     float64
# fuel_Eco                        float64
# fuel_Petrol                     float64
# seller_type_Dealer              float64
# seller_type_Individual          float64
# seller_type_Trustmark_Dealer    float64
# transmission_Automatic          float64
# transmission_Manual             float64
# owner_First Owner               float64
# owner_Fourth & Above Owner      float64
# owner_Second Owner              float64
# owner_Third Owner               float64
# name                              int64
# year                              int64
# selling_price                     int64
# km_driven                         int64
# mileage                         float64
# engine                          float64
# max_power                       float64
# seats                           float64
# dtype: object

# %%
project.columns
# Out:
# Index(['fuel_Diesel', 'fuel_Eco', 'fuel_Petrol', 'seller_type_Dealer',
#        'seller_type_Individual', 'seller_type_Trustmark_Dealer',
#        'transmission_Automatic', 'transmission_Manual', 'owner_First Owner',
#        'owner_Fourth & Above Owner', 'owner_Second Owner', 'owner_Third Owner',
#        'name', 'year', 'selling_price', 'km_driven', 'mileage', 'engine',
#        'max_power', 'seats'],
#       dtype='object')

# %%
project = project.rename(columns={"owner_First Owner":"owner_first_owner",
                                 "owner_Fourth & Above Owner":"owner_fourthandabove",
                                 "owner_Second Owner":"owner_Second_Owner",
                                 "owner_Third Owner":"owner_Third_Owner"})

# %%
project
# Out:
#       fuel_Diesel  fuel_Eco  fuel_Petrol  seller_type_Dealer  \
# 0            1.00      0.00         0.00                0.00
# 1            1.00      0.00         0.00                0.00
# 2            0.00      0.00         1.00                0.00
# 3            1.00      0.00         0.00                0.00
# 4            0.00      0.00         1.00                0.00
# ...           ...       ...          ...                 ...
# 6710         0.00      0.00         1.00                0.00
# 6711         1.00      0.00         0.00                0.00
# 6712         0.00      0.00         1.00                0.00
# 6713         1.00      0.00         0.00                0.00
# 6714         1.00      0.00         0.00                0.00
#
#       seller_type_Individual  seller_type_Trustmark_Dealer  \
# 0                       1.00                          0.00
# 1                       1.00                          0.00
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = project.drop(["selling_price"],axis=1)
y = project["selling_price"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
lir = RandomForestRegressor()

# %%
lir.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = lir.predict(x_test)

# %%
y_pred
# Out:
# array([664255.        , 203244.94      , 112580.        , ...,
#        169830.        , 383003.31333333, 380220.        ], shape=(1343,))

# %%
y_test
# Out:
# 1363     509999
# 3171     150000
# 2201      65000
# 5119    1350000
# 6106     175000
#          ...
# 2384     465000
# 3214     217000
# 3542     150000
# 6383     300000
# 5741     400000
# Name: selling_price, Length: 1343, dtype: int64

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_pred,y_test))
# Out:
# 0.8962395552883382

# %%
fuel = input("enter fuel type:")
seller = input("enter seller type:")
transmission = input("enter transmission type:")
owner = input("enter owner type:")
name = input("enter your name:")
year = int(input("enter year in which you bought:"))
km = float(input("kms you drove:"))
mileage = float(input("mileage of your car:"))
engine = int(input("enter cc you got:"))
power = float(input("power in bhp or hp:"))
seats = int(input("enter number of seats:"))
# Out:
# enter fuel type: diesel
# enter seller type: individual
# enter transmission type: manual
# enter owner type: second owner
# enter your name: maruti
# enter year in which you bought: 2016
# kms you drove: 250000
# mileage of your car: 16
# enter cc you got: 1345
# power in bhp or hp: 80
# enter number of seats: 4

# %%
if fuel=="Diesel":
    fuel_Diesel=1
    fuel_Petrol=0
    fuel_Eco=0
elif fuel=="Petrol":
    fuel_Diesel=0
    fuel_Petrol=1
    fuel_Eco=0
else:
    fuel_Diesel=0
    fuel_Petrol=0
    fuel_Eco=1

# %%
if seller == "Dealer":
    seller_type_Dealer = 1
    seller_type_Individual = 0
    seller_type_Trustmark_Dealer = 0

elif seller == "Individual":
    seller_type_Dealer = 0
    seller_type_Individual = 1
    seller_type_Trustmark_Dealer = 0

else:
    seller_type_Dealer = 0
    seller_type_Individual = 0
    seller_type_Trustmark_Dealer = 1

# %%
if owner=="First Owner":
    owner_First_Owner=1
    owner_FourthndAbove=0
    owner_Second_Owner=0
    owner_Third_Owner=0

elif owner=="Fourth and Above Owner":
    owner_First_Owner=0
    owner_FourthndAbove=1
    owner_Second_Owner=0
    owner_Third_Owner=0
    
elif owner=="Second Owner":
    owner_First_Owner=0
    owner_FourthndAbove=0
    owner_Second_Owner=1
    owner_Third_Owner=0

elif owner=="Third Owner":
    owner_First_Owner=0
    owner_FourthndAbove=0
    owner_Second_Owner=0
    owner_Third_Owner=1

else:
    owner_First_Owner=0
    owner_FourthndAbove=0
    owner_Second_Owner=0
    owner_Third_Owner=0

# %%
if transmission=="Automatic":
    transmission_Automatic=1
    transmission_Manual=0

elif transmission=="Manual":
    transmission_Automatic=0
    transmission_Manual=1

else:
    transmission_Automatic=0
    transmission_Manual=0

# %%
import numpy as np

# %%
#from sklearn.preprocessing import StandardScaler

# %%
#std = StandardScaler()

# %%
#x = std.fit_transform(x,y)

# %%
#x = std.transform(x)

# %%
#pred = lir.predict(x)

# %%
luxury = ["Land", "Mercedes", "Audi", "BMW", "Jaguar", "Volvo", "Jeep", "Isuzu", "Kia"]
budget = ["Maruti", "Datsun", "Chevrolet", "Fiat", "Ambassador"]

brand_name = name.strip().split()[0]  # name is the input() variable

if brand_name in luxury:
    name_encoded = 2
elif brand_name in budget:
    name_encoded = 0
else:
    name_encoded = 1

# %%
input_data = pd.DataFrame([{
    'fuel_Diesel'                    : fuel_Diesel,
    'fuel_Eco'                       : fuel_Eco,
    'fuel_Petrol'                    : fuel_Petrol,
    'seller_type_Dealer'             : seller_type_Dealer,
    'seller_type_Individual'         : seller_type_Individual,
    'seller_type_Trustmark_Dealer'   : seller_type_Trustmark_Dealer,
    'transmission_Automatic'         : transmission_Automatic,
    'transmission_Manual'            : transmission_Manual,
    'owner_First_Owner'              : owner_First_Owner,
    'owner_FourthndAbove'            : owner_FourthndAbove,
    'owner_Second_Owner'             : owner_Second_Owner,
    'owner_Third_Owner'              : owner_Third_Owner,
    'name'                           : name_encoded,
    'year'                           : year,
    'selling_price'                  : 0,
    'km_driven'                      : km,
    'mileage'                        : mileage,
    'engine'                         : engine,
    'max_power'                      : power,
    'seats'                          : seats
}])

input_data = input_data.drop(columns=['selling_price'])
input_data = input_data.reindex(columns=x_train.columns, fill_value=0)

# %%
predicted_price = lir.predict(input_data)[0]
print(f'estimated selling price: rs. {predicted_price:,.0f}')
# Out:
# estimated selling price: rs. 413,530

# %%
import numpy as np

# %%
y = np.log1p(project["selling_price"])
predicted_price = np.expm1(lir.predict(input_data)[0])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3436\1638148068.py:2: RuntimeWarning: overflow encountered in expm1
#   predicted_price = np.expm1(lir.predict(input_data)[0])

# %%
p["car_age"] = 2026-p["year"]
p = p.drop(columns=["year"])

# %%
from sklearn.model_selection import RandomizedSearchCV
params = {'n_estimators':[100,200,300],'max_depth':[10,20, None],'min_samples_split':[2,5,10]}
rf = RandomizedSearchCV(RandomForestRegressor(),params,cv=5,scoring='r2')
rf.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': [10, 20, None],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300]},
#                    scoring='r2')

# %%
from xgboost import XGBRegressor
model = XGBRegressor(n_estimators=300,learning_rate=0.05,max_depth=6)
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=300,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
p = p[p["selling_price"]<5000000]

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model,x,y,cv=5,scoring='r2')
print("avg r2:",scores.mean())
print("consistancy:",scores.std())
# Out:
# avg r2: 0.9163438367430541
# consistancy: 0.005137417173899525
